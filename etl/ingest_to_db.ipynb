# %%
import pandas as pd
import sqlite3
import os

# %%
files = os.listdir(os.getcwd())

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'ddl_create_tables.py',
#  'ingest_to_db.ipynb',
#  'scrapper.py']

# %%
DB_PATH = "../db/footbase.db"  # or whatever you named it

if os.path.exists(DB_PATH):
    os.remove(DB_PATH)
    print("🧹 Old database deleted.")
else:
    print("✅ No existing DB found, starting clean.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[22], line 4
#       1 DB_PATH = "../db/footbase.db"  # or whatever you named it
#       3 if os.path.exists(DB_PATH):
# ----> 4     os.remove(DB_PATH)
#       5     print("🧹 Old database deleted.")
#       6 else:
#
# PermissionError: [WinError 32] O arquivo já está sendo usado por outro processo: '../db/footbase.db'

# %%
# Create a cursor to run SQL commands
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('competitions',), ('sqlite_sequence',), ('teams',), ('matches',)]

# %%
cursor.execute("PRAGMA table_info(matches);")
for col in cursor.fetchall():
    print(col)
# Out:
# (0, 'match_id', 'INTEGER', 0, None, 1)
# (1, 'competition_id', 'INTEGER', 0, None, 0)
# (2, 'season', 'TEXT', 0, None, 0)
# (3, 'date', 'TEXT', 0, None, 0)
# (4, 'home_team_id', 'INTEGER', 0, None, 0)
# (5, 'away_team_id', 'INTEGER', 0, None, 0)
# (6, 'home_goals', 'INTEGER', 0, None, 0)
# (7, 'away_goals', 'INTEGER', 0, None, 0)
# (8, 'result', 'TEXT', 0, None, 0)
# (9, 'home_shots', 'INTEGER', 0, None, 0)
# (10, 'away_shots', 'INTEGER', 0, None, 0)
# (11, 'home_shots_on_target', 'INTEGER', 0, None, 0)
# (12, 'away_shots_on_target', 'INTEGER', 0, None, 0)
# (13, 'odds_home', 'REAL', 0, None, 0)
# (14, 'odds_draw', 'REAL', 0, None, 0)
# (15, 'odds_away', 'REAL', 0, None, 0)
