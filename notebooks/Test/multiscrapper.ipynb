# %%
import pandas as pd
import os

BASE_URL = "https://www.football-data.co.uk/mmz4281"
LEAGUES = {
    "E0": "Premier League",
    "SC0": "Scottish Premiership",
    "B1": "Belgian Pro League",
    "G1": "Greek Super League"
}

SEASONS = ["1718", "1819", "1920", "2021", "2122", "2223", "2324", "2425"]

CSV_DIR = "../data/raw"
os.makedirs(CSV_DIR, exist_ok=True)

for code, league_name in LEAGUES.items():
    for season in SEASONS:
        url = f"{BASE_URL}/{season}/{code}.csv"
        print(f"📥 Downloading {league_name} {season} from {url}")
        try:
            df = pd.read_csv(url)
            if df.empty:
                print(f"⚠️ Skipped {league_name} {season} (empty file)")
                continue
        except Exception as e:
            print(f"❌ Error loading {league_name} {season}: {e}")
            continue

        df = df.rename(columns={
            'Date': 'date',
            'HomeTeam': 'home_team',
            'AwayTeam': 'away_team',
            'FTHG': 'home_goals',
            'FTAG': 'away_goals',
            'FTR': 'result',
            'HS': 'home_shots',
            'AS': 'away_shots',
            'HST': 'home_shots_on_target',
            'AST': 'away_shots_on_target',
            'B365H': 'odds_home',
            'B365D': 'odds_draw',
            'B365A': 'odds_away'
        })

        keep_cols = [
            'date', 'home_team', 'away_team', 'home_goals', 'away_goals', 'result',
            'home_shots', 'away_shots', 'home_shots_on_target', 'away_shots_on_target',
            'odds_home', 'odds_draw', 'odds_away'
        ]
        df = df[[col for col in keep_cols if col in df.columns]]
        df['league'] = league_name
        df['season'] = f"20{season[:2]}/{season[2:]}"

        # Save file
        fname = f"{league_name.replace(' ', '_')}_{season}.csv"
        fpath = os.path.join(CSV_DIR, fname)
        df.to_csv(fpath, index=False)
        print(f"💾 Saved {fpath} ({len(df)} rows)")
# Out:
# 📥 Downloading Eredivisie 1718 from https://www.football-data.co.uk/mmz4281/1718/N1.csv
# 💾 Saved ../data/raw\Eredivisie_1718.csv (306 rows)
# 📥 Downloading Eredivisie 1819 from https://www.football-data.co.uk/mmz4281/1819/N1.csv
# 💾 Saved ../data/raw\Eredivisie_1819.csv (306 rows)
# 📥 Downloading Eredivisie 1920 from https://www.football-data.co.uk/mmz4281/1920/N1.csv
# 💾 Saved ../data/raw\Eredivisie_1920.csv (232 rows)
# 📥 Downloading Eredivisie 2021 from https://www.football-data.co.uk/mmz4281/2021/N1.csv
# 💾 Saved ../data/raw\Eredivisie_2021.csv (306 rows)
# 📥 Downloading Eredivisie 2122 from https://www.football-data.co.uk/mmz4281/2122/N1.csv
# 💾 Saved ../data/raw\Eredivisie_2122.csv (306 rows)
# 📥 Downloading Eredivisie 2223 from https://www.football-data.co.uk/mmz4281/2223/N1.csv
# 💾 Saved ../data/raw\Eredivisie_2223.csv (306 rows)
# 📥 Downloading Eredivisie 2324 from https://www.football-data.co.uk/mmz4281/2324/N1.csv
# 💾 Saved ../data/raw\Eredivisie_2324.csv (306 rows)
# 📥 Downloading Eredivisie 2425 from https://www.football-data.co.uk/mmz4281/2425/N1.csv
# 💾 Saved ../data/raw\Eredivisie_2425.csv (306 rows)
# 📥 Downloading Bundesliga 1718 from https://www.football-data.co.uk/mmz4281/1718/D1.csv
# 💾 Saved ../data/raw\Bundesliga_1718.csv (306 rows)
# 📥 Downloading Primeira Liga 1718 from https://www.football-data.co.uk/mmz4281/1718/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_1718.csv (306 rows)
# 📥 Downloading Primeira Liga 1819 from https://www.football-data.co.uk/mmz4281/1819/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_1819.csv (306 rows)
# 📥 Downloading Primeira Liga 1920 from https://www.football-data.co.uk/mmz4281/1920/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_1920.csv (306 rows)
# 📥 Downloading Primeira Liga 2021 from https://www.football-data.co.uk/mmz4281/2021/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_2021.csv (306 rows)
# 📥 Downloading Primeira Liga 2122 from https://www.football-data.co.uk/mmz4281/2122/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_2122.csv (306 rows)
# 📥 Downloading Primeira Liga 2223 from https://www.football-data.co.uk/mmz4281/2223/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_2223.csv (306 rows)
# 📥 Downloading Primeira Liga 2324 from https://www.football-data.co.uk/mmz4281/2324/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_2324.csv (306 rows)
# 📥 Downloading Primeira Liga 2425 from https://www.football-data.co.uk/mmz4281/2425/P1.csv
# 💾 Saved ../data/raw\Primeira_Liga_2425.csv (306 rows)

# %%
df = pd.read_csv(r"../data/raw/Bundesliga_1819.csv")

# %%
df.head()
# Out:
#          date           home_team      away_team  home_goals  away_goals  \
# 0  24/08/2018       Bayern Munich     Hoffenheim           3           1
# 1  25/08/2018  Fortuna Dusseldorf       Augsburg           1           2
# 2  25/08/2018            Freiburg  Ein Frankfurt           0           2
# 3  25/08/2018              Hertha       Nurnberg           1           0
# 4  25/08/2018          M'gladbach     Leverkusen           2           0
#
#   result  home_shots  away_shots  home_shots_on_target  away_shots_on_target  \
# 0      H          16           8                     5                     5
# 1      A           9          14                     5                     7
# 2      A          22          10                     6                     2
# 3      H          10          12                     3                     3
# 4      H          17          13                     7                     3
#
#    odds_home  odds_draw  odds_away      league   season
# 0       1.20       7.50      12.00  Bundesliga  2018/19
# 1       2.37       3.25       3.00  Bundesliga  2018/19
# 2       2.30       3.30       3.25  Bundesliga  2018/19
# 3       2.04       3.40       3.75  Bundesliga  2018/19
# 4       2.80       3.50       2.45  Bundesliga  2018/19

# %%
import pandas as pd
import os

BASE_URL = "https://www.football-data.co.uk/mmz4281"
LEAGUES = {
    "E0": "Premier League",
    "SC0": "Scottish Premiership",
    "B1": "Belgian Pro League",
    "G1": "Greek Super League"
}

SEASONS = ["1718", "1819", "1920", "2021", "2122", "2223", "2324", "2425"]

CSV_DIR = "../data/raw"
os.makedirs(CSV_DIR, exist_ok=True)

for code, league_name in LEAGUES.items():
    for season in SEASONS:
        url = f"{BASE_URL}/{season}/{code}.csv"
        print(f"📥 Downloading {league_name} {season} from {url}")
        try:
            df = pd.read_csv(url)
            if df.empty:
                print(f"⚠️ Skipped {league_name} {season} (empty file)")
                continue
        except Exception as e:
            print(f"❌ Error loading {league_name} {season}: {e}")
            continue

        df = df.rename(columns={
            'Date': 'date',
            'HomeTeam': 'home_team',
            'AwayTeam': 'away_team',
            'FTHG': 'home_goals',
            'FTAG': 'away_goals',
            'FTR': 'result',
            'HS': 'home_shots',
            'AS': 'away_shots',
            'HST': 'home_shots_on_target',
            'AST': 'away_shots_on_target',
            'B365H': 'odds_home',
            'B365D': 'odds_draw',
            'B365A': 'odds_away'
        })

        keep_cols = [
            'date', 'home_team', 'away_team', 'home_goals', 'away_goals', 'result',
            'home_shots', 'away_shots', 'home_shots_on_target', 'away_shots_on_target',
            'odds_home', 'odds_draw', 'odds_away'
        ]
        df = df[[col for col in keep_cols if col in df.columns]]
        df['league'] = league_name
        df['season'] = f"20{season[:2]}/{season[2:]}"

        # Save file
        fname = f"{league_name.replace(' ', '_')}_{season}.csv"
        fpath = os.path.join(CSV_DIR, fname)
        df.to_csv(fpath, index=False)
        print(f"💾 Saved {fpath} ({len(df)} rows)")
# Out:
# 📥 Downloading Premier League 1718 from https://www.football-data.co.uk/mmz4281/1718/E0.csv
# 💾 Saved ../data/raw\Premier_League_1718.csv (380 rows)
# 📥 Downloading Premier League 1819 from https://www.football-data.co.uk/mmz4281/1819/E0.csv
# 💾 Saved ../data/raw\Premier_League_1819.csv (380 rows)
# 📥 Downloading Premier League 1920 from https://www.football-data.co.uk/mmz4281/1920/E0.csv
# 💾 Saved ../data/raw\Premier_League_1920.csv (380 rows)
# 📥 Downloading Premier League 2021 from https://www.football-data.co.uk/mmz4281/2021/E0.csv
# 💾 Saved ../data/raw\Premier_League_2021.csv (380 rows)
# 📥 Downloading Premier League 2122 from https://www.football-data.co.uk/mmz4281/2122/E0.csv
# 💾 Saved ../data/raw\Premier_League_2122.csv (380 rows)
# 📥 Downloading Premier League 2223 from https://www.football-data.co.uk/mmz4281/2223/E0.csv
# 💾 Saved ../data/raw\Premier_League_2223.csv (380 rows)
# 📥 Downloading Premier League 2324 from https://www.football-data.co.uk/mmz4281/2324/E0.csv
# 💾 Saved ../data/raw\Premier_League_2324.csv (380 rows)
# 📥 Downloading Premier League 2425 from https://www.football-data.co.uk/mmz4281/2425/E0.csv
# 💾 Saved ../data/raw\Premier_League_2425.csv (380 rows)
# 📥 Downloading Scottish Premiership 1718 from https://www.football-data.co.uk/mmz4281/1718/SC0.csv
# 💾 Saved ../data/raw\Scottish_Premiership_1718.csv (228 rows)
# 📥 Downloading Scottish Premiership 1819 from https://www.football-data.co.uk/mmz4281/1819/SC0.csv
# ❌ Error loading Scottish Premiership 1819: 'utf-8' codec can't decode byte 0xa0 in position 42709: invalid start byte
# 📥 Downloading Scottish Premiership 1920 from https://www.football-data.co.uk/mmz4281/1920/SC0.csv
# 💾 Saved ../data/raw\Scottish_Premiership_1920.csv (179 rows)
# 📥 Downloading Scottish Premiership 2021 from https://www.football-data.co.uk/mmz4281/2021/SC0.csv
# 💾 Saved ../data/raw\Scottish_Premiership_2021.csv (228 rows)
# 📥 Downloading Scottish Premiership 2122 from https://www.football-data.co.uk/mmz4281/2122/SC0.csv
# 💾 Saved ../data/raw\Scottish_Premiership_2122.csv (228 rows)
# 📥 Downloading Scottish Premiership 2223 from https://www.football-data.co.uk/mmz4281/2223/SC0.csv
