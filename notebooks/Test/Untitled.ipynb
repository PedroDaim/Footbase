# %%
from understat import Understat
import aiohttp
import asyncio
import nest_asyncio
import pandas as pd

# %%
nest_asyncio.apply()

async def get_understat_data():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        leagues = ["EPL", "La_Liga", "Bundesliga", "Serie_A", "Ligue_1"]
        seasons = list(range(2017, 2025))
        all_data = []

        for league in leagues:
            for season in seasons:
                try:
                    matches = await understat.get_league_results(league, season)
                    df = pd.DataFrame(matches)
                    df["league"] = league
                    df["season"] = season
                    all_data.append(df)
                    print(f"✅ {league} {season}: {len(df)} matches")
                except Exception as e:
                    print(f"⚠️ {league} {season}: {e}")

        return pd.concat(all_data, ignore_index=True)

data = asyncio.run(get_understat_data())
data.to_csv("../data/raw/understat_xg_data.csv", index=False)
print("💾 Saved Understat data!")
# Out:
# ✅ EPL 2017: 380 matches
# ✅ EPL 2018: 380 matches
# ✅ EPL 2019: 380 matches
# ✅ EPL 2020: 380 matches
# ✅ EPL 2021: 380 matches
# ✅ EPL 2022: 380 matches
# ✅ EPL 2023: 380 matches
# ✅ EPL 2024: 380 matches
# ✅ La_Liga 2017: 380 matches
# ✅ La_Liga 2018: 380 matches
# ✅ La_Liga 2019: 380 matches
# ✅ La_Liga 2020: 380 matches
# ✅ La_Liga 2021: 380 matches
# ✅ La_Liga 2022: 380 matches
# ✅ La_Liga 2023: 380 matches
# ✅ La_Liga 2024: 380 matches
# ✅ Bundesliga 2017: 306 matches
# ✅ Bundesliga 2018: 306 matches
# ✅ Bundesliga 2019: 306 matches
# ✅ Bundesliga 2020: 306 matches
# ✅ Bundesliga 2021: 306 matches
# ✅ Bundesliga 2022: 306 matches
# ✅ Bundesliga 2023: 306 matches
# ✅ Bundesliga 2024: 306 matches
# ✅ Serie_A 2017: 380 matches
# ✅ Serie_A 2018: 380 matches
# ✅ Serie_A 2019: 380 matches
# ✅ Serie_A 2020: 380 matches
# ✅ Serie_A 2021: 380 matches
# ✅ Serie_A 2022: 380 matches
# ✅ Serie_A 2023: 380 matches
# ✅ Serie_A 2024: 380 matches
# ✅ Ligue_1 2017: 380 matches
# ✅ Ligue_1 2018: 380 matches
# ✅ Ligue_1 2019: 279 matches
# ✅ Ligue_1 2020: 380 matches
# ✅ Ligue_1 2021: 380 matches
# ✅ Ligue_1 2022: 380 matches
# ✅ Ligue_1 2023: 306 matches
# ✅ Ligue_1 2024: 306 matches
# 💾 Saved Understat data!

# %%
df = pd.read_csv(r"../data/raw/understat_xg_data.csv")

# %%
df.head()
# Out:
#      id  isResult                                                  h  \
# 0  7119      True  {'id': '83', 'title': 'Arsenal', 'short_title'...
# 1  7120      True  {'id': '90', 'title': 'Watford', 'short_title'...
# 2  7121      True  {'id': '76', 'title': 'West Bromwich Albion', ...
# 3  7122      True  {'id': '74', 'title': 'Southampton', 'short_ti...
# 4  7123      True  {'id': '80', 'title': 'Chelsea', 'short_title'...
#
#                                                    a                 goals  \
# 0  {'id': '75', 'title': 'Leicester', 'short_titl...  {'h': '4', 'a': '3'}
# 1  {'id': '87', 'title': 'Liverpool', 'short_titl...  {'h': '3', 'a': '3'}
# 2  {'id': '73', 'title': 'Bournemouth', 'short_ti...  {'h': '1', 'a': '0'}
# 3  {'id': '84', 'title': 'Swansea', 'short_title'...  {'h': '0', 'a': '0'}
# 4  {'id': '92', 'title': 'Burnley', 'short_title'...  {'h': '2', 'a': '3'}
#
#                                   xG             datetime  \
# 0   {'h': '2.54329', 'a': '1.46495'}  2017-08-11 19:45:00
# 1   {'h': '2.17647', 'a': '2.61549'}  2017-08-12 12:30:00
# 2  {'h': '1.18399', 'a': '0.378659'}  2017-08-12 15:00:00
# 3  {'h': '2.21748', 'a': '0.406196'}  2017-08-12 15:00:00
# 4  {'h': '1.35651', 'a': '0.564237'}  2017-08-12 15:00:00
#
#                                         forecast league  season
# 0   {'w': '0.628', 'd': '0.2154', 'l': '0.1566'}    EPL    2017
# 1   {'w': '0.2452', 'd': '0.287', 'l': '0.4678'}    EPL    2017
# 2  {'w': '0.5875', 'd': '0.3056', 'l': '0.1069'}    EPL    2017
# 3  {'w': '0.8262', 'd': '0.1377', 'l': '0.0361'}    EPL    2017
# 4   {'w': '0.5899', 'd': '0.284', 'l': '0.1261'}    EPL    2017

# %%
import ast

# Convert stringified dicts into real dicts
for col in ["h", "a", "goals", "xG", "forecast"]:
    df[col] = df[col].apply(ast.literal_eval)

# %%
df["home_team"] = df["h"].apply(lambda x: x["title"])
df["away_team"] = df["a"].apply(lambda x: x["title"])

df["home_goals"] = df["goals"].apply(lambda x: int(x["h"]))
df["away_goals"] = df["goals"].apply(lambda x: int(x["a"]))

df["home_xg"] = df["xG"].apply(lambda x: float(x["h"]))
df["away_xg"] = df["xG"].apply(lambda x: float(x["a"]))

# %%
df.head()
# Out:
#      id  isResult                                                  h  \
# 0  7119      True  {'id': '83', 'title': 'Arsenal', 'short_title'...
# 1  7120      True  {'id': '90', 'title': 'Watford', 'short_title'...
# 2  7121      True  {'id': '76', 'title': 'West Bromwich Albion', ...
# 3  7122      True  {'id': '74', 'title': 'Southampton', 'short_ti...
# 4  7123      True  {'id': '80', 'title': 'Chelsea', 'short_title'...
#
#                                                    a                 goals  \
# 0  {'id': '75', 'title': 'Leicester', 'short_titl...  {'h': '4', 'a': '3'}
# 1  {'id': '87', 'title': 'Liverpool', 'short_titl...  {'h': '3', 'a': '3'}
# 2  {'id': '73', 'title': 'Bournemouth', 'short_ti...  {'h': '1', 'a': '0'}
# 3  {'id': '84', 'title': 'Swansea', 'short_title'...  {'h': '0', 'a': '0'}
# 4  {'id': '92', 'title': 'Burnley', 'short_title'...  {'h': '2', 'a': '3'}
#
#                                   xG             datetime  \
# 0   {'h': '2.54329', 'a': '1.46495'}  2017-08-11 19:45:00
# 1   {'h': '2.17647', 'a': '2.61549'}  2017-08-12 12:30:00
# 2  {'h': '1.18399', 'a': '0.378659'}  2017-08-12 15:00:00
# 3  {'h': '2.21748', 'a': '0.406196'}  2017-08-12 15:00:00
# 4  {'h': '1.35651', 'a': '0.564237'}  2017-08-12 15:00:00
#
#                                         forecast league  season  \
# 0   {'w': '0.628', 'd': '0.2154', 'l': '0.1566'}    EPL    2017
# 1   {'w': '0.2452', 'd': '0.287', 'l': '0.4678'}    EPL    2017
# 2  {'w': '0.5875', 'd': '0.3056', 'l': '0.1069'}    EPL    2017
# 3  {'w': '0.8262', 'd': '0.1377', 'l': '0.0361'}    EPL    2017
# 4   {'w': '0.5899', 'd': '0.284', 'l': '0.1261'}    EPL    2017
#
#               home_team    away_team  home_goals  away_goals  home_xg  \
# 0               Arsenal    Leicester           4           3  2.54329
# 1               Watford    Liverpool           3           3  2.17647
# 2  West Bromwich Albion  Bournemouth           1           0  1.18399
# 3           Southampton      Swansea           0           0  2.21748
# 4               Chelsea      Burnley           2           3  1.35651
#
#     away_xg
# 0  1.464950
# 1  2.615490
# 2  0.378659
# 3  0.406196
# 4  0.564237

# %%
df["date"] = pd.to_datetime(df["datetime"]).dt.date
df["season"] = df["season"].astype(str)

df_clean = df[[
    "date", "home_team", "away_team",
    "home_goals", "away_goals",
    "home_xg", "away_xg",
    "league", "season"
]]

# %%
df_clean.head()
# Out:
#          date             home_team    away_team  home_goals  away_goals  \
# 0  2017-08-11               Arsenal    Leicester           4           3
# 1  2017-08-12               Watford    Liverpool           3           3
# 2  2017-08-12  West Bromwich Albion  Bournemouth           1           0
# 3  2017-08-12           Southampton      Swansea           0           0
# 4  2017-08-12               Chelsea      Burnley           2           3
#
#    home_xg   away_xg league season
# 0  2.54329  1.464950    EPL   2017
# 1  2.17647  2.615490    EPL   2017
# 2  1.18399  0.378659    EPL   2017
# 3  2.21748  0.406196    EPL   2017
# 4  1.35651  0.564237    EPL   2017

# %%
df_clean.to_csv("../data/raw/understat_xg_data_clean.csv", index=False)

# %%
clean_xg = pd.read_csv("../data/raw/understat_xg_data_clean.csv")

# %%
clean_xg.head()
# Out:
#          date             home_team    away_team  home_goals  away_goals  \
# 0  2017-08-11               Arsenal    Leicester           4           3
# 1  2017-08-12               Watford    Liverpool           3           3
# 2  2017-08-12  West Bromwich Albion  Bournemouth           1           0
# 3  2017-08-12           Southampton      Swansea           0           0
# 4  2017-08-12               Chelsea      Burnley           2           3
#
#    home_xg   away_xg league  season
# 0  2.54329  1.464950    EPL    2017
# 1  2.17647  2.615490    EPL    2017
# 2  1.18399  0.378659    EPL    2017
# 3  2.21748  0.406196    EPL    2017
# 4  1.35651  0.564237    EPL    2017
